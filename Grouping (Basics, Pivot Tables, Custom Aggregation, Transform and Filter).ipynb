# %% [markdown]
# # Grouping (Basics, Pivot Tables, Crosstabs, Custom Aggregation)

# %% [markdown]
# ### First groupby aggregation
#
# Let's begin our usage of the `groupby` method by finding the average salary of every employee by department from the City of Houston dataset.

# %%
import pandas as pd
emp = pd.read_csv('../data/employee.csv')
emp.head(3)
# Out:
#                    dept                       title   hire_date    salary  \
# 0                Police             POLICE SERGEANT  2001-12-03  87545.38
# 1                 Other  ASSISTANT CITY ATTORNEY II  2010-11-15  82182.00
# 2  Houston Public Works     SENIOR SLUDGE PROCESSOR  2006-01-09  49275.00
#
#     sex      race
# 0  Male     White
# 1  Male  Hispanic
# 2  Male     Black

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise 1
#
# <span  style="color:green; font-size:16px">Find the maximum salary for each sex.</span>

# %%
emp.groupby('sex').agg(max_sal = ('salary','max'))
# Out:
#          max_sal
# sex
# Female  342784.0
# Male    342784.0

# %% [markdown]
# ### Exercise 2
#
# <span  style="color:green; font-size:16px">Find the median salary for each department.</span>

# %%
(emp.groupby('dept')
    .agg(med_sal = ('salary', 'median')))
# Out:
#                           med_sal
# dept
# Fire                     61921.08
# Health & Human Services  50773.00
# Houston Airport System   44200.00
# Houston Public Works     46841.50
# Library                  34611.00
# Other                    53324.00
# Parks & Recreation       31512.00
# Police                   68116.62
# Solid Waste Management   39333.00

# %% [markdown]
# ### Exercise 3
#
# <span style="color:green; font-size:16px">Find the average salary for each race. Return a DataFrame with the race as a column.</span>

# %%
(emp.groupby('race',as_index = False)
    .agg(avg_sal = ('salary','mean')))
# Out:
#               race       avg_sal
# 0            Asian  65316.197885
# 1            Black  52264.180833
# 2         Hispanic  54811.349584
# 3  Native American  58153.109371
# 4            White  66611.692973

# %% [markdown]
# ### Exercise 4
#
# <span style="color:green; font-size:16px">Find the number of employees in each department.</span>

# %%
(emp.groupby('dept')
    .agg(num_emp = ('title', 'size')))
# Out:
#                          num_emp
# dept
# Fire                        4376
# Health & Human Services     1353
# Houston Airport System      1216
# Houston Public Works        4190
# Library                      563
# Other                       3373
# Parks & Recreation          1152
# Police                      7573
# Solid Waste Management       512

# %% [markdown]
# ### Exercise 5
#
# <span style="color:green; font-size:16px">Find the number of unique titles there are for each department.</span>

# %%
(emp.groupby('dept')
    .agg(unq_tit = ('title', 'nunique')))
# Out:
#                          unq_tit
# dept
# Fire                          77
# Health & Human Services      161
# Houston Airport System       137
# Houston Public Works         215
# Library                       66
# Other                        358
# Parks & Recreation           109
# Police                       145
# Solid Waste Management        44

# %% [markdown]
# ### Exercise 6
#
# <span style="color:green; font-size:16px">Find the index of the employee with the maximum salary for each department and then use those index values to select their entire rows from the original DataFrame.</span>

# %%
indeex = (emp.groupby('dept')
             .agg(inx_sal = ('salary','idxmax')))['inx_sal']

emp.loc[indeex]
# Out:
#                           dept                        title   hire_date  \
# 1732                      Fire                 PHYSICIAN,MD  2014-09-27
# 8405   Health & Human Services           CHIEF PHYSICIAN,MD  2017-07-31
# 3897    Houston Airport System            AVIATION DIRECTOR  2010-06-01
# 10704     Houston Public Works        PUBLIC WORKS DIRECTOR  2005-08-10
# 7564                   Library             LIBRARY DIRECTOR  2005-11-07
# 13338                    Other                CITY ATTORNEY  2016-05-02
# 11679       Parks & Recreation  PARKS & RECREATION DIRECTOR  2017-07-05
# 4413                    Police                 POLICE CHIEF  2016-11-30
# 20244   Solid Waste Management         SOLID WASTE DIRECTOR  2001-05-14
#
#          salary     sex      race
# 1732   342784.0    Male     White
# 8405   186685.0  Female     White
# 3897   275000.0    Male  Hispanic
# 10704  275000.0  Female     White
# 7564   170000.0  Female     Black
# 13338  275000.0    Male     Black
# 11679  150000.0    Male     White
# 4413   280000.0    Male  Hispanic
# 20244  195000.0    Male     Black

# %% [markdown]
# ### Use the NYC deaths dataset for the remaining exercises
#
# Execute the cell below to read in the NYC deaths dataset and use it to answer the following exercises.

# %%
deaths = pd.read_csv('../data/nyc_deaths.csv')
deaths.head(3)
# Out:
#    year      cause sex      race  deaths
# 0  2007  Accidents   F     Asian      32
# 1  2007  Accidents   F     Black      87
# 2  2007  Accidents   F  Hispanic      71

# %% [markdown]
# ### Exercise 7
#
# <span style="color:green; font-size:16px">What year had the most deaths?</span>

# %%
#Series
(deaths.groupby('year')
       .agg(per_year = ('deaths','sum'))
       .idxmax())
# Out:
# per_year    2008
# dtype: int64

# %%
#DataFrame
year_deaths = deaths.groupby('year').agg(total=('deaths', 'sum'))
year_deaths.agg(['max', 'idxmax'])
# Out:
#         total
# max     54138
# idxmax   2008

# %% [markdown]
# ### Exercise 8
#
# <span  style="color:green; font-size:16px">Find the total number of deaths by race and sort by most to least.</span>

# %%
(deaths.groupby('race')
       .agg(race_death = ('deaths','sum'))
       .sort_values('race_death', ascending = False))
# Out:
#           race_death
# race
# White         206487
# Black         111116
# Hispanic       74802
# Asian          26355
# Unknown         6238

# %% [markdown]
# ### Exercise 9
#
# <span  style="color:green; font-size:16px">Find the total number of deaths by cause and then select the five highest causes.</span>

# %%
(deaths.groupby('cause')
       .agg(death_cause = ('deaths','sum'))
       .sort_values('death_cause', ascending = False)
       .head(5))
# Out:
#                    death_cause
# cause
# Heart Disease           147551
# Cancer                  106367
# Other                    77999
# Flu and Pneumonia        18678
# Diabetes                 13794

# %% [markdown]
# # Grouping and Aggregating with Multiple Columns

# %% [markdown]
# ## Exercises
# Execute the following cell to read in the City of Houston employee data and use it for the first few exercises.

# %%
emp = pd.read_csv('../data/employee.csv')
emp.head(3)
# Out:
#                    dept                       title   hire_date    salary  \
# 0                Police             POLICE SERGEANT  2001-12-03  87545.38
# 1                 Other  ASSISTANT CITY ATTORNEY II  2010-11-15  82182.00
# 2  Houston Public Works     SENIOR SLUDGE PROCESSOR  2006-01-09  49275.00
#
#     sex      race
# 0  Male     White
# 1  Male  Hispanic
# 2  Male     Black

# %% [markdown]
# ### Exercise 1
#
# <span  style="color:green; font-size:16px">For each department and sex, find the number of unique position titles, the total number of employees, and the average salary. Make sure there is no multi-level index.</span>

# %%
(emp.groupby(['dept','sex'], as_index = False) 
    .agg(uni_pos = ('title','nunique'),
         num_emp = ('sex','size'),
         avg_sal = ('salary','mean'))
    .round({'avg_sal' : -3})
)
# Out:
#                        dept     sex  uni_pos  num_emp  avg_sal
# 0                      Fire  Female       51      240  62000.0
# 1                      Fire    Male       54     4136  60000.0
# 2   Health & Human Services  Female      136      987  54000.0
# 3   Health & Human Services    Male      110      366  59000.0
# 4    Houston Airport System  Female       85      443  51000.0
# 5    Houston Airport System    Male      113      773  57000.0
# 6      Houston Public Works  Female      151     1195  51000.0
# 7      Houston Public Works    Male      180     2995  51000.0
# 8                   Library  Female       55      404  41000.0
# 9                   Library    Male       44      159  44000.0
# 10                    Other  Female      246     1819  61000.0
# 11                    Other    Male      282     1554  62000.0
# 12       Parks & Recreation  Female       64      364  37000.0
# 13       Parks & Recreation    Male       82      788  37000.0
# 14                   Police  Female      110     1777  58000.0
# 15                   Police    Male      106     5796  69000.0
# 16   Solid Waste Management  Female       26      129  47000.0
# 17   Solid Waste Management    Male       30      383  43000.0

# %% [markdown]
# ### Exercise 2
#
# <span  style="color:green; font-size:16px">For each department, race, and sex find the min and max and salaries.</span>

# %%
(emp.groupby(['dept','race','sex'])
    .agg(min_sal = ('salary','min'),
         max_sal = ('salary','max'))
)
# Out:
#                                                min_sal    max_sal
# dept                   race            sex
# Fire                   Asian           Female  39104.0  342784.00
#                                        Male    28024.0  342784.00
#                        Black           Female  16411.0  342784.00
#                                        Male    28024.0  342784.00
#                        Hispanic        Female  28024.0   89590.02
# ...                                                ...        ...
# Solid Waste Management Hispanic        Female  32053.0  100119.00
#                                        Male    27851.0   60840.00
#                        Native American Female  31325.0   31325.00
#                        White           Female  36962.0  103275.00
#                                        Male    31325.0   83441.00
#
# [89 rows x 2 columns]

# %%
pd.set_option('display.max_columns',100)
college = pd.read_csv('../data/college.csv')
college.head(3)
# Out:
#                                 instnm        city stabbr  hbcu  menonly  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
#
#    womenonly  relaffil  satvrmid  satmtmid  distanceonly     ugds  ugds_white  \
# 0        0.0         0     424.0     420.0           0.0   4206.0      0.0333
# 1        0.0         0     570.0     565.0           0.0  11383.0      0.5922
# 2        0.0         1       NaN       NaN           1.0    291.0      0.2990
#
#    ugds_black  ugds_hisp  ugds_asian  ugds_aian  ugds_nhpi  ugds_2mor  \
# 0      0.9353     0.0055      0.0019     0.0024     0.0019     0.0000
# 1      0.2600     0.0283      0.0518     0.0022     0.0007     0.0368
# 2      0.4192     0.0069      0.0034     0.0000     0.0000     0.0000
#
#    ugds_nra  ugds_unkn  pptug_ef  curroper  pctpell  pctfloan  ug25abv  \
# 0    0.0059     0.0138    0.0656         1   0.7356    0.8284   0.1049
# 1    0.0179     0.0100    0.2607         1   0.3460    0.5214   0.2422
# 2    0.0000     0.2715    0.4536         1   0.6801    0.7795   0.8540
#
#   md_earn_wne_p10 grad_debt_mdn_supp
# 0           30300              33888
# 1           39700            21941.5
# 2           40100              23370

# %% [markdown]
# ### Exercise 3
#
# <span  style="color:green; font-size:16px">Which city name appears the most frequently. Do this in two different ways. Do it once with and once without the `groupby` method?</span>

# %%
college.groupby('city').agg(size=('stabbr', 'size'))
# Out:
#               size
# city
# Aberdeen         3
# Abilene          5
# Abingdon         2
# Abington         1
# Ada              3
# ...            ...
# Yucaipa          1
# Yucca Valley     1
# Yukon            1
# Yuma             1
# Zanesville       3
#
# [2514 rows x 1 columns]

# %%
college.city.value_counts().nlargest(5)
# Out:
# New York       87
# Chicago        78
# Houston        72
# Los Angeles    56
# Miami          51
# Name: city, dtype: int64

# %% [markdown]
# ### Exercise 4
#
# <span style="color:green; font-size:16px">Does the city 'Houston' only appear in the state of Texas (abbreviated 'TX')?</span>

# %%
college.query('city == "Houston"')[['stabbr']].value_counts()
# Out:
# stabbr
# TX        71
# MO         1
# dtype: int64

# %%
college[['city', 'stabbr']].query('city == "Houston"') \
                           .drop_duplicates(subset='stabbr')
# Out:
#          city stabbr
# 3617  Houston     TX
# 5366  Houston     MO

# %% [markdown]
# ### Exercise 5
#
# <span style="color:green; font-size:16px">Find the maximum undergraduate population for each state?</span>

# %%
(college.groupby(['stabbr'])
        .agg(max_ugds = ('ugds','max'))
).head(10)
# Out:
#         max_ugds
# stabbr
# AK       12865.0
# AL       29851.0
# AR       21405.0
# AS        1276.0
# AZ      151558.0
# CA       44744.0
# CO       25873.0
# CT       18016.0
# DC       10433.0
# DE       18222.0

# %% [markdown]
# ### Exercise 6
#
# <span style="color:green; font-size:16px">Find the largest college from each state. From those colleges, find the difference between the largest and smallest.</span>

# %%
(college.groupby(['stabbr'])
        .agg(max_ugds = ('ugds','max')).agg(['max','min'])
        .diff(-1)
)
# Out:
#      max_ugds
# max  150956.0
# min       NaN

# %% [markdown]
# ### Exercise 7
#
# <span style="color:green; font-size:16px">Find the name and population of the largest college per state.</span>

# %%
c2 = college.set_index('instnm')

(c2.groupby(['stabbr'])
        .agg(max_college = ('ugds','idxmax'),
                max_ugds = ('ugds', 'max'))
).head(10)
# Out:
#                              max_college  max_ugds
# stabbr
# AK        University of Alaska Anchorage   12865.0
# AL             The University of Alabama   29851.0
# AR                University of Arkansas   21405.0
# AS      American Samoa Community College    1276.0
# AZ         University of Phoenix-Arizona  151558.0
# CA                    Ashford University   44744.0
# CO        University of Colorado Boulder   25873.0
# CT             University of Connecticut   18016.0
# DC          George Washington University   10433.0
# DE                University of Delaware   18222.0

# %% [markdown]
# ### Exercise 8
#
# <span  style="color:green; font-size:16px">Do distance only schools tend to have more or less student population than non-distance-only schools?</span>

# %%
(college.groupby('distanceonly').agg(sum_ugds = ('ugds','mean'))
)
# Out:
#                  sum_ugds
# distanceonly
# 0.0           2334.648135
# 1.0           6245.743590

# %% [markdown]
# ### Exercise 9
#
# <span style="color:green; font-size:16px">Do distance only schools tend to be more or less religiously affiliated than non-distance-only schools?</span>

# %%
(college.groupby('distanceonly').agg(sum_ugds = ('relaffil','mean'))
)
# Out:
#               sum_ugds
# distanceonly
# 0.0           0.149635
# 1.0           0.050000

# %% [markdown]
# ### Exercise 10
#
# <span  style="color:green; font-size:16px">What state has the lowest percentage of currently operating schools of those that have religious affiliation?</span>

# %%
(college.query('relaffil == 1').groupby('stabbr') 
                               .agg(operating = ('curroper','mean'))
                               .nsmallest(5,'operating')
                               .round(2)
)
# Out:
#         operating
# stabbr
# UT           0.40
# AZ           0.44
# NV           0.50
# CA           0.59
# CT           0.65

# %% [markdown]
# ### Exercise 11
#
# <span  style="color:green; font-size:16px">Find the top 5 historically black colleges that have the highest undergraduate white percentage (ugds_white)?</span>

# %%
(college.query('hbcu == 1').groupby('instnm')
                           .agg(white = ('ugds_white','mean'))
                           .nlargest(5, 'white')
)
# Out:
#                                               white
# instnm
# Bluefield State College                      0.8437
# Gadsden State Community College              0.6921
# West Virginia State University               0.5816
# Shelton State Community College              0.5613
# H Councill Trenholm State Community College  0.3951

# %% [markdown]
# # Grouping with Pivot Tables

# %% [markdown]
# ## Exercises
#
# Execute the following cell to read in the flights dataset and insert columns for the day and month name. Use it for the following exercises.

# %%
import pandas as pd
flights = pd.read_csv('../data/flights.csv', parse_dates=['date'])
flights.insert(1, 'day_of_week', flights['date'].dt.day_name())
flights.insert(2, 'month', flights['date'].dt.month_name())
flights.head(3)
# Out:
#         date day_of_week    month airline origin dest  dep_time  arr_time  \
# 0 2018-01-01      Monday  January      UA    LAS  IAH       100       547
# 1 2018-01-01      Monday  January      WN    DEN  PHX       515       720
# 2 2018-01-01      Monday  January      B6    JFK  BOS       550       657
#
#    cancelled  air_time  distance  carrier_delay  weather_delay  nas_delay  \
# 0          0     134.0    1222.0              0              0          0
# 1          0      91.0     602.0              0              0          0
# 2          0      39.0     187.0              0             83          8
#
#    security_delay  late_aircraft_delay
# 0               0                    0
# 1               0                    0
# 2               0                    0

# %% [markdown]
# ### Exercise 1
#
# <span style="color:green; font-size:16px">What is the average carrier delay for each day of the week for each airline? Highlight the worst day of the week for each airline.</span>

# %%
(flights.pivot_table(index = 'airline', columns = 'day_of_week',\
                     values = 'carrier_delay', aggfunc = 'mean')
        .style.highlight_max(axis = 1)
        .format('{:.1f}'))
# Out:
# <style type="text/css">
# #T_86576_row0_col4, #T_86576_row1_col4, #T_86576_row2_col3, #T_86576_row3_col0, #T_86576_row4_col4, #T_86576_row5_col1, #T_86576_row6_col2, #T_86576_row7_col3, #T_86576_row8_col2, #T_86576_row9_col4, #T_86576_row10_col6, #T_86576_row11_col3, #T_86576_row12_col2, #T_86576_row13_col0, #T_86576_row14_col4, #T_86576_row15_col1 {
#   background-color: yellow;
# }
# </style>
# <table id="T_86576_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >day_of_week</th>
#       <th class="col_heading level0 col0" >Friday</th>
#       <th class="col_heading level0 col1" >Monday</th>
#       <th class="col_heading level0 col2" >Saturday</th>
#       <th class="col_heading level0 col3" >Sunday</th>
#       <th class="col_heading level0 col4" >Thursday</th>
#       <th class="col_heading level0 col5" >Tuesday</th>
#       <th class="col_heading level0 col6" >Wednesday</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >airline</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86576_level0_row0" class="row_heading level0 row0" >9E</th>
#       <td id="T_86576_row0_col0" class="data row0 col0" >3.4</td>
#       <td id="T_86576_row0_col1" class="data row0 col1" >4.7</td>
#       <td id="T_86576_row0_col2" class="data row0 col2" >1.8</td>
#       <td id="T_86576_row0_col3" class="data row0 col3" >3.3</td>
#       <td id="T_86576_row0_col4" class="data row0 col4" >7.7</td>
#       <td id="T_86576_row0_col5" class="data row0 col5" >3.0</td>
#       <td id="T_86576_row0_col6" class="data row0 col6" >4.2</td>
#     </tr>
#     <tr>
#       <th id="T_86576_level0_row1" class="row_heading level0 row1" >AA</th>
#       <td id="T_86576_row1_col0" class="data row1 col0" >3.9</td>
#       <td id="T_86576_row1_col1" class="data row1 col1" >3.7</td>
#       <td id="T_86576_row1_col2" class="data row1 col2" >3.8</td>
#       <td id="T_86576_row1_col3" class="data row1 col3" >3.8</td>
#       <td id="T_86576_row1_col4" class="data row1 col4" >4.9</td>
#       <td id="T_86576_row1_col5" class="data row1 col5" >4.1</td>
#       <td id="T_86576_row1_col6" class="data row1 col6" >2.8</td>
#     </tr>
#     <tr>
#       <th id="T_86576_level0_row2" class="row_heading level0 row2" >AS</th>
#       <td id="T_86576_row2_col0" class="data row2 col0" >3.0</td>
#       <td id="T_86576_row2_col1" class="data row2 col1" >1.5</td>
#       <td id="T_86576_row2_col2" class="data row2 col2" >3.6</td>
#       <td id="T_86576_row2_col3" class="data row2 col3" >3.7</td>
#       <td id="T_86576_row2_col4" class="data row2 col4" >2.9</td>
#       <td id="T_86576_row2_col5" class="data row2 col5" >2.6</td>
#       <td id="T_86576_row2_col6" class="data row2 col6" >2.1</td>
#     </tr>
#     <tr>
#       <th id="T_86576_level0_row3" class="row_heading level0 row3" >B6</th>
#       <td id="T_86576_row3_col0" class="data row3 col0" >7.0</td>
#       <td id="T_86576_row3_col1" class="data row3 col1" >4.0</td>
#       <td id="T_86576_row3_col2" class="data row3 col2" >5.5</td>
#       <td id="T_86576_row3_col3" class="data row3 col3" >5.1</td>
#       <td id="T_86576_row3_col4" class="data row3 col4" >5.1</td>
#       <td id="T_86576_row3_col5" class="data row3 col5" >6.2</td>
#       <td id="T_86576_row3_col6" class="data row3 col6" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_86576_level0_row4" class="row_heading level0 row4" >DL</th>
#       <td id="T_86576_row4_col0" class="data row4 col0" >3.5</td>
#       <td id="T_86576_row4_col1" class="data row4 col1" >2.6</td>
#       <td id="T_86576_row4_col2" class="data row4 col2" >3.0</td>
#       <td id="T_86576_row4_col3" class="data row4 col3" >3.6</td>
#       <td id="T_86576_row4_col4" class="data row4 col4" >3.9</td>
#       <td id="T_86576_row4_col5" class="data row4 col5" >3.3</td>
#       <td id="T_86576_row4_col6" class="data row4 col6" >3.3</td>
#     </tr>
#     <tr>
#       <th id="T_86576_level0_row5" class="row_heading level0 row5" >EV</th>
#       <td id="T_86576_row5_col0" class="data row5 col0" >5.2</td>
#       <td id="T_86576_row5_col1" class="data row5 col1" >8.5</td>
#       <td id="T_86576_row5_col2" class="data row5 col2" >2.4</td>
#       <td id="T_86576_row5_col3" class="data row5 col3" >7.2</td>
#       <td id="T_86576_row5_col4" class="data row5 col4" >0.0</td>
#       <td id="T_86576_row5_col5" class="data row5 col5" >6.0</td>
#       <td id="T_86576_row5_col6" class="data row5 col6" >1.7</td>
#     </tr>
#     <tr>
#       <th id="T_86576_level0_row6" class="row_heading level0 row6" >F9</th>
#       <td id="T_86576_row6_col0" class="data row6 col0" >7.9</td>
#       <td id="T_86576_row6_col1" class="data row6 col1" >3.6</td>
#       <td id="T_86576_row6_col2" class="data row6 col2" >9.5</td>
#       <td id="T_86576_row6_col3" class="data row6 col3" >4.1</td>
#       <td id="T_86576_row6_col4" class="data row6 col4" >7.8</td>
#       <td id="T_86576_row6_col5" class="data row6 col5" >6.6</td>
#       <td id="T_86576_row6_col6" class="data row6 col6" >1.8</td>
#     </tr>
#     <tr>
#       <th id="T_86576_level0_row7" class="row_heading level0 row7" >MQ</th>
#       <td id="T_86576_row7_col0" class="data row7 col0" >2.1</td>
#       <td id="T_86576_row7_col1" class="data row7 col1" >4.2</td>
#       <td id="T_86576_row7_col2" class="data row7 col2" >0.0</td>
#       <td id="T_86576_row7_col3" class="data row7 col3" >5.4</td>
#       <td id="T_86576_row7_col4" class="data row7 col4" >4.2</td>
#       <td id="T_86576_row7_col5" class="data row7 col5" >1.5</td>
#       <td id="T_86576_row7_col6" class="data row7 col6" >2.3</td>
#     </tr>
#     <tr>
#       <th id="T_86576_level0_row8" class="row_heading level0 row8" >NK</th>
#       <td id="T_86576_row8_col0" class="data row8 col0" >2.2</td>
#       <td id="T_86576_row8_col1" class="data row8 col1" >1.5</td>
#       <td id="T_86576_row8_col2" class="data row8 col2" >5.8</td>
#       <td id="T_86576_row8_col3" class="data row8 col3" >1.7</td>
#       <td id="T_86576_row8_col4" class="data row8 col4" >2.2</td>
#       <td id="T_86576_row8_col5" class="data row8 col5" >2.5</td>
#       <td id="T_86576_row8_col6" class="data row8 col6" >1.2</td>
#     </tr>
#     <tr>
#       <th id="T_86576_level0_row9" class="row_heading level0 row9" >OH</th>
#       <td id="T_86576_row9_col0" class="data row9 col0" >6.3</td>
#       <td id="T_86576_row9_col1" class="data row9 col1" >4.9</td>
#       <td id="T_86576_row9_col2" class="data row9 col2" >2.5</td>
#       <td id="T_86576_row9_col3" class="data row9 col3" >9.2</td>
#       <td id="T_86576_row9_col4" class="data row9 col4" >19.9</td>
#       <td id="T_86576_row9_col5" class="data row9 col5" >0.5</td>
#       <td id="T_86576_row9_col6" class="data row9 col6" >1.5</td>
#     </tr>
#     <tr>
#       <th id="T_86576_level0_row10" class="row_heading level0 row10" >OO</th>
#       <td id="T_86576_row10_col0" class="data row10 col0" >6.5</td>
#       <td id="T_86576_row10_col1" class="data row10 col1" >9.5</td>
#       <td id="T_86576_row10_col2" class="data row10 col2" >2.0</td>
#       <td id="T_86576_row10_col3" class="data row10 col3" >4.8</td>
#       <td id="T_86576_row10_col4" class="data row10 col4" >3.5</td>
#       <td id="T_86576_row10_col5" class="data row10 col5" >1.9</td>
#       <td id="T_86576_row10_col6" class="data row10 col6" >10.2</td>
#     </tr>
#     <tr>
#       <th id="T_86576_level0_row11" class="row_heading level0 row11" >UA</th>
#       <td id="T_86576_row11_col0" class="data row11 col0" >3.2</td>
#       <td id="T_86576_row11_col1" class="data row11 col1" >2.4</td>
#       <td id="T_86576_row11_col2" class="data row11 col2" >3.2</td>
#       <td id="T_86576_row11_col3" class="data row11 col3" >4.0</td>
#       <td id="T_86576_row11_col4" class="data row11 col4" >3.7</td>
#       <td id="T_86576_row11_col5" class="data row11 col5" >3.7</td>
#       <td id="T_86576_row11_col6" class="data row11 col6" >2.6</td>
#     </tr>
#     <tr>

# %% [markdown]
# ### Exercise 2
#
# <span style="color:green; font-size:16px">Use a pivot table to find the total number of canceled flights for each origin airport and airline. Place the airlines in the columns. Use the result to find the origin airport with the most cancelled flights for each airline. Also return this maximum number of cancelled flights.</span>

# %%
flights.pivot_table(index = 'origin', columns = 'airline',\
                    values = 'cancelled', aggfunc = 'sum').agg(['max','idxmax'], axis = 1)
# Out:
#          max idxmax
# origin
# ATL     19.0     DL
# BOS     41.0     AA
# CLT     33.0     AA
# DCA     31.0     YX
# DEN     10.0     UA
# DFW     33.0     AA
# DTW      8.0     DL
# EWR     27.0     UA
# IAH      7.0     AA
# JFK     17.0     B6
# LAS      8.0     AA
# LAX     18.0     WN
# LGA     31.0     YX
# MCO     12.0     B6
# MSP      6.0     YX
# ORD     38.0     AA
# PHL     24.0     AA
# PHX      8.0     AA
# SEA      9.0     AS
# SFO     14.0     WN

# %% [markdown]
# ### Exercise 3
#
# <span style="color:green; font-size:16px">Find the total distance flown for each airline for each month. Highlight the month with the most number of miles flown and use the style `format` method to put commas in the numbers so that they are easier to read.</span>

# %%
(flights.pivot_table(index = 'airline', columns = 'month',
                    values = 'distance', aggfunc = 'sum')
                   .style.highlight_max(axis = 1)
                   .format('{:,.0f}'))
# Out:
# <style type="text/css">
# #T_30702_row0_col1, #T_30702_row1_col5, #T_30702_row2_col6, #T_30702_row3_col5, #T_30702_row4_col5, #T_30702_row5_col3, #T_30702_row6_col4, #T_30702_row7_col5, #T_30702_row8_col6, #T_30702_row9_col4, #T_30702_row10_col9, #T_30702_row11_col5, #T_30702_row12_col7, #T_30702_row13_col6, #T_30702_row14_col2, #T_30702_row15_col5 {
#   background-color: yellow;
# }
# </style>
# <table id="T_30702_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th class="col_heading level0 col0" >April</th>
#       <th class="col_heading level0 col1" >August</th>
#       <th class="col_heading level0 col2" >December</th>
#       <th class="col_heading level0 col3" >February</th>
#       <th class="col_heading level0 col4" >January</th>
#       <th class="col_heading level0 col5" >July</th>
#       <th class="col_heading level0 col6" >June</th>
#       <th class="col_heading level0 col7" >March</th>
#       <th class="col_heading level0 col8" >May</th>
#       <th class="col_heading level0 col9" >November</th>
#       <th class="col_heading level0 col10" >October</th>
#       <th class="col_heading level0 col11" >September</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >airline</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30702_level0_row0" class="row_heading level0 row0" >9E</th>
#       <td id="T_30702_row0_col0" class="data row0 col0" >54,592</td>
#       <td id="T_30702_row0_col1" class="data row0 col1" >62,216</td>
#       <td id="T_30702_row0_col2" class="data row0 col2" >46,032</td>
#       <td id="T_30702_row0_col3" class="data row0 col3" >51,784</td>
#       <td id="T_30702_row0_col4" class="data row0 col4" >47,230</td>
#       <td id="T_30702_row0_col5" class="data row0 col5" >53,868</td>
#       <td id="T_30702_row0_col6" class="data row0 col6" >50,421</td>
#       <td id="T_30702_row0_col7" class="data row0 col7" >61,460</td>
#       <td id="T_30702_row0_col8" class="data row0 col8" >42,423</td>
#       <td id="T_30702_row0_col9" class="data row0 col9" >42,275</td>
#       <td id="T_30702_row0_col10" class="data row0 col10" >48,106</td>
#       <td id="T_30702_row0_col11" class="data row0 col11" >45,745</td>
#     </tr>
#     <tr>
#       <th id="T_30702_level0_row1" class="row_heading level0 row1" >AA</th>
#       <td id="T_30702_row1_col0" class="data row1 col0" >1,586,655</td>
#       <td id="T_30702_row1_col1" class="data row1 col1" >1,649,436</td>
#       <td id="T_30702_row1_col2" class="data row1 col2" >1,444,276</td>
#       <td id="T_30702_row1_col3" class="data row1 col3" >1,371,620</td>
#       <td id="T_30702_row1_col4" class="data row1 col4" >1,473,883</td>
#       <td id="T_30702_row1_col5" class="data row1 col5" >1,669,007</td>
#       <td id="T_30702_row1_col6" class="data row1 col6" >1,619,325</td>
#       <td id="T_30702_row1_col7" class="data row1 col7" >1,528,361</td>
#       <td id="T_30702_row1_col8" class="data row1 col8" >1,545,453</td>
#       <td id="T_30702_row1_col9" class="data row1 col9" >1,409,540</td>
#       <td id="T_30702_row1_col10" class="data row1 col10" >1,588,285</td>
#       <td id="T_30702_row1_col11" class="data row1 col11" >1,482,841</td>
#     </tr>
#     <tr>
#       <th id="T_30702_level0_row2" class="row_heading level0 row2" >AS</th>
#       <td id="T_30702_row2_col0" class="data row2 col0" >454,146</td>
#       <td id="T_30702_row2_col1" class="data row2 col1" >451,512</td>
#       <td id="T_30702_row2_col2" class="data row2 col2" >399,787</td>
#       <td id="T_30702_row2_col3" class="data row2 col3" >201,275</td>
#       <td id="T_30702_row2_col4" class="data row2 col4" >195,553</td>
#       <td id="T_30702_row2_col5" class="data row2 col5" >455,061</td>
#       <td id="T_30702_row2_col6" class="data row2 col6" >496,358</td>
#       <td id="T_30702_row2_col7" class="data row2 col7" >199,288</td>
#       <td id="T_30702_row2_col8" class="data row2 col8" >495,090</td>
#       <td id="T_30702_row2_col9" class="data row2 col9" >391,304</td>
#       <td id="T_30702_row2_col10" class="data row2 col10" >409,479</td>
#       <td id="T_30702_row2_col11" class="data row2 col11" >429,045</td>
#     </tr>
#     <tr>
#       <th id="T_30702_level0_row3" class="row_heading level0 row3" >B6</th>
#       <td id="T_30702_row3_col0" class="data row3 col0" >352,234</td>
#       <td id="T_30702_row3_col1" class="data row3 col1" >404,458</td>
#       <td id="T_30702_row3_col2" class="data row3 col2" >427,097</td>
#       <td id="T_30702_row3_col3" class="data row3 col3" >348,189</td>
#       <td id="T_30702_row3_col4" class="data row3 col4" >385,517</td>
#       <td id="T_30702_row3_col5" class="data row3 col5" >478,230</td>
#       <td id="T_30702_row3_col6" class="data row3 col6" >443,151</td>
#       <td id="T_30702_row3_col7" class="data row3 col7" >382,666</td>
#       <td id="T_30702_row3_col8" class="data row3 col8" >410,877</td>
#       <td id="T_30702_row3_col9" class="data row3 col9" >384,038</td>
#       <td id="T_30702_row3_col10" class="data row3 col10" >425,712</td>
#       <td id="T_30702_row3_col11" class="data row3 col11" >384,008</td>
#     </tr>
#     <tr>
#       <th id="T_30702_level0_row4" class="row_heading level0 row4" >DL</th>
#       <td id="T_30702_row4_col0" class="data row4 col0" >1,265,266</td>
#       <td id="T_30702_row4_col1" class="data row4 col1" >1,315,865</td>
#       <td id="T_30702_row4_col2" class="data row4 col2" >1,160,997</td>
#       <td id="T_30702_row4_col3" class="data row4 col3" >997,216</td>
#       <td id="T_30702_row4_col4" class="data row4 col4" >1,017,440</td>
#       <td id="T_30702_row4_col5" class="data row4 col5" >1,396,697</td>
#       <td id="T_30702_row4_col6" class="data row4 col6" >1,292,928</td>
#       <td id="T_30702_row4_col7" class="data row4 col7" >1,215,516</td>
#       <td id="T_30702_row4_col8" class="data row4 col8" >1,253,361</td>
#       <td id="T_30702_row4_col9" class="data row4 col9" >1,100,681</td>
#       <td id="T_30702_row4_col10" class="data row4 col10" >1,214,950</td>
#       <td id="T_30702_row4_col11" class="data row4 col11" >1,173,359</td>
#     </tr>
#     <tr>
#       <th id="T_30702_level0_row5" class="row_heading level0 row5" >EV</th>
#       <td id="T_30702_row5_col0" class="data row5 col0" >6,847</td>
#       <td id="T_30702_row5_col1" class="data row5 col1" >1,194</td>
#       <td id="T_30702_row5_col2" class="data row5 col2" >3,933</td>
#       <td id="T_30702_row5_col3" class="data row5 col3" >11,854</td>
#       <td id="T_30702_row5_col4" class="data row5 col4" >10,186</td>
#       <td id="T_30702_row5_col5" class="data row5 col5" >927</td>
#       <td id="T_30702_row5_col6" class="data row5 col6" >5,926</td>
#       <td id="T_30702_row5_col7" class="data row5 col7" >4,511</td>
#       <td id="T_30702_row5_col8" class="data row5 col8" >3,569</td>
#       <td id="T_30702_row5_col9" class="data row5 col9" >1,592</td>
#       <td id="T_30702_row5_col10" class="data row5 col10" >2,587</td>
#       <td id="T_30702_row5_col11" class="data row5 col11" >995</td>
#     </tr>
#     <tr>
#       <th id="T_30702_level0_row6" class="row_heading level0 row6" >F9</th>
#       <td id="T_30702_row6_col0" class="data row6 col0" >117,439</td>
#       <td id="T_30702_row6_col1" class="data row6 col1" >97,777</td>
#       <td id="T_30702_row6_col2" class="data row6 col2" >97,846</td>
#       <td id="T_30702_row6_col3" class="data row6 col3" >97,879</td>
#       <td id="T_30702_row6_col4" class="data row6 col4" >118,067</td>
#       <td id="T_30702_row6_col5" class="data row6 col5" >84,417</td>
#       <td id="T_30702_row6_col6" class="data row6 col6" >116,116</td>
#       <td id="T_30702_row6_col7" class

# %% [markdown]
# ### Exercise 4
#
# <span style="color:green; font-size:16px">Create a pivot table that shows the number of flights flown for every day of the week for every month.</span>

# %%
(flights.pivot_table(index = 'day_of_week', columns = 'month',
                    aggfunc = 'size'))
# Out:
# month        April  August  December  February  January  July  June  March  \
# day_of_week
# Friday         786    1006       707       748      673   808  1005    974
# Monday         943     785       840       725      862   936   792    734
# Saturday       644     592       750       544      536   677   817    705
# Sunday         898     776       897       639      696   932   809    687
# Thursday       818     982       759       753      739   765   842    884
# Tuesday        755     757       634       716      821  1012   779    676
# Wednesday      754     963       695       719      838   780   822    751
#
# month         May  November  October  September
# day_of_week
# Friday        766       887      773        739
# Monday        798       710      961        742
# Saturday      597       624      554        742
# Sunday        726       737      711        902
# Thursday     1058       871      790        761
# Tuesday       913       707      939        719
# Wednesday     894       709      894        762

# %% [markdown]
# ### Exercise 5
#
# <span style="color:green; font-size:16px">In exercise 4, the months and days of week are ordered alphabetically. It would be better if these values were ordered chronologically. Can you return a result that has both groups in the correct order. Use Monday as the first day of the week.</span>

# %%
month_dtype = pd.CategoricalDtype(['January', 'February', 'March', 'April', 'May', 'June', 'July',
       'August', 'September', 'October', 'November', 'December'], ordered = True)

day_dtype = pd.CategoricalDtype(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday',
       'Sunday'], ordered = True)

flights = flights.astype({'day_of_week' : day_dtype, 'month' : month_dtype})

# %%
flights.pivot_table(index = 'day_of_week', columns = 'month',\
                   values = 'dest', aggfunc = 'size', sort = False)
# Out:
# month        January  February  March  April   May  June  July  August  \
# day_of_week
# Monday           862       725    734    943   798   792   936     785
# Tuesday          821       716    676    755   913   779  1012     757
# Wednesday        838       719    751    754   894   822   780     963
# Thursday         739       753    884    818  1058   842   765     982
# Friday           673       748    974    786   766  1005   808    1006
# Saturday         536       544    705    644   597   817   677     592
# Sunday           696       639    687    898   726   809   932     776
#
# month        September  October  November  December
# day_of_week
# Monday             742      961       710       840
# Tuesday            719      939       707       634
# Wednesday          762      894       709       695
# Thursday           761      790       871       759
# Friday             739      773       887       707
# Saturday           742      554       624       750
# Sunday             902      711       737       897

# %% [markdown]
# ### Exercise 6
#
# <span style="color:green; font-size:16px">Create a new column in the flights dataset called `'dep_time_hour'` and set it equal to the hour (this will be an integer 0 through 23) of the flight. Find the average carrier delay for every month and dep_time_hour. Place the month in the columns.</span>

# %%
flights['dep_time_hour'] =flights['dep_time'] // 100 
(flights.pivot_table(index = 'dep_time_hour', columns = 'day_of_week',
                    values = 'carrier_delay', aggfunc = 'mean')
        .round(1))
# Out:
# day_of_week    Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# dep_time_hour
# 0                 0.2      3.6        1.2       2.4     6.5       1.7     2.4
# 1                 0.0      0.0        1.1       0.7     0.0       1.7     2.3
# 2                 NaN      NaN        0.0       NaN     NaN       0.0     0.0
# 4                 NaN      NaN        NaN       NaN     0.0       NaN     NaN
# 5                 5.9      1.5        1.8       2.4     4.4       3.0     1.8
# 6                 2.5      2.8        2.6       2.8     5.2       4.0     3.5
# 7                 2.0      3.5        1.8       3.7     3.8       4.1     1.8
# 8                 3.6      3.1        7.2       4.3     2.3       4.0     3.7
# 9                 3.1      2.8        2.5       3.8     3.3       3.4     3.0
# 10                2.8      2.9        2.1       3.4     3.3       3.2     2.1
# 11                3.8      3.4        2.0       2.0     2.5       1.6     3.3
# 12                3.1      4.0        3.1       4.1     3.0       4.2     4.3
# 13                2.3      3.6        3.1       2.8     4.7       2.6     2.9
# 14                3.0      4.1        2.3       5.0     1.9       3.6     3.1
# 15                3.1      3.5        3.0       4.9     3.8       3.7     4.7
# 16                3.0      3.3        2.5       4.6     3.8       3.8     3.2
# 17                4.3      3.7        4.9       4.4     3.4       3.2     5.0
# 18                4.1      4.3        2.9       9.4     2.8       5.3     4.1
# 19                2.9      2.6        2.9       4.7     6.8       3.3     6.3
# 20                5.3      4.3        4.2       4.8     4.8       4.1     4.3
# 21                2.6      6.1        3.4       7.6     6.7       3.4     4.5
# 22                4.2      7.6        4.5       4.4     6.1       2.5     5.6
# 23                5.1      2.4        0.9       4.2    10.9      10.3     2.6

# %% [markdown]
# ### Exercise 7
#
# <span style="color:green; font-size:16px">Use both `groupby` and `pivot_table` to compute the average and median distance flown by day of the week.</span>

# %%
flights.groupby('day_of_week').agg(median_dist=('distance', 'median'),
                                   mean_dist=('distance', 'mean'))
# Out:
#              median_dist    mean_dist
# day_of_week
# Monday             912.0  1071.351038
# Tuesday            888.0  1051.831141
# Wednesday          868.0  1052.546290
# Thursday           907.0  1066.285073
# Friday             868.0  1050.703404
# Saturday           937.0  1107.159728
# Sunday             925.0  1092.702657

# %%
(flights.pivot_table(index = 'day_of_week', \
                   values = 'distance', aggfunc = ['median', 'mean']))
# Out:
#               median         mean
#             distance     distance
# day_of_week
# Monday         912.0  1071.351038
# Tuesday        888.0  1051.831141
# Wednesday      868.0  1052.546290
# Thursday       907.0  1066.285073
# Friday         868.0  1050.703404
# Saturday       937.0  1107.159728
# Sunday         925.0  1092.702657

# %% [markdown]
# ### Exercise 8
#
# <span style="color:green; font-size:16px">Use a dictionary in the `groupby` `agg` method to calculate the mean, median, min, and max of the air time for every airline.</span>

# %%
flights.groupby('airline').agg({'arr_time' : ['mean','median','min','max']})
# Out:
#             arr_time
#                 mean  median  min   max
# airline
# 9E       1501.621022  1449.0  657  2356
# AA       1488.175815  1527.0    1  2359
# AS       1478.302404  1536.0    1  2359
# B6       1456.797170  1503.0    1  2400
# DL       1520.030754  1542.0    2  2359
# EV       1494.584795  1549.0  712  2200
# F9       1453.113935  1543.0    2  2359
# MQ       1541.801609  1600.0  620  2325
# NK       1485.779305  1521.5    1  2400
# OH       1572.451362  1639.0  747  2340
# OO       1483.955875  1527.0    4  2359
# UA       1487.313163  1525.0    1  2359
# VX       1460.004662  1546.0    3  2359
# WN       1488.442590  1530.0    5  2355
# YV       1484.489712  1523.0    1  2353
# YX       1524.359688  1529.0   10  2359

# %% [markdown]
# ### Exercise 9
#
# <span style="color:green; font-size:16px">Without using the `agg` method calculate the number of unique destinations for each airline.</span>

# %%
flights.groupby('airline')[['dest']].nunique()
# Out:
#          dest
# airline
# 9E         13
# AA         20
# AS         18
# B6         19
# DL         20
# EV          8
# F9         17
# MQ         12
# NK         16
# OH          9
# OO         19
# UA         19
# VX         12
# WN         15
# YV         10
# YX         14

# %% [markdown]
# ### Exercise 10
#
# <span style="color:green; font-size:16px">Calculate the mean of every numeric column for each airline and origin without using the `agg` method.</span>

# %%
flights.groupby(['airline','origin']).mean(numeric_only = True)
# Out:
#                    dep_time     arr_time  cancelled    air_time     distance  \
# airline origin
# 9E      ATL      729.714286   840.142857   0.000000  105.142857   689.000000
#         BOS     1320.029412  1453.970588   0.049020   47.103093   191.558824
#         CLT     1254.613636  1461.238636   0.068182   82.926829   554.397727
#         DCA     1168.218182  1309.563636   0.018182   44.629630   216.490909
#         DFW     1346.068182  1682.136364   0.011364  137.080460  1054.022727
# ...                     ...          ...        ...         ...          ...
# YX      JFK     1519.901961  1677.705882   0.078431   57.191489   278.725490
#         LGA     1272.184569  1456.931921   0.046899   91.452229   546.311649
#         MSP     1167.055556  1494.888889   0.037037  114.737179   843.049383
#         ORD     1374.639535  1515.186047   0.027132   86.163347   589.135659
#         PHL     1515.984375  1690.390625   0.000000   71.359375   391.703125
#
#                 carrier_delay  weather_delay  nas_delay  security_delay  \
# airline origin
# 9E      ATL          0.000000       0.000000   3.857143             0.0
#         BOS          2.284314       0.029412   8.607843             0.0
#         CLT          5.261364       0.000000   4.022727             0.0
#         DCA         10.945455       0.000000   1.309091             0.0
#         DFW          2.840909       0.738636   3.772727             0.0
# ...                       ...            ...        ...             ...
# YX      JFK          0.000000       0.000000   3.078431             0.0
#         LGA          3.028744       0.422088   3.836611             0.0
#         MSP          1.265432       0.037037   7.962963             0.0
#         ORD          2.093023       0.352713   7.015504             0.0
#         PHL          3.984375       0.031250   2.140625             0.0
#
#                 late_aircraft_delay  dep_time_hour
# airline origin
# 9E      ATL                0.000000       7.000000
#         BOS                4.176471      13.049020
#         CLT                4.295455      12.352273
#         DCA                2.163636      11.527273
#         DFW               11.875000      13.193182
# ...                             ...            ...
# YX      JFK                2.980392      14.960784
#         LGA                4.751891      12.541604
#         MSP                5.067901      11.388889
#         ORD                7.569767      13.550388
#         PHL                4.000000      14.875000
#
# [240 rows x 11 columns]

# %% [markdown]
# # Custom Aggregation

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise 1
#
# <span style="color:green; font-size:16px">What are the three airlines with the least number of flights?</span>

# %%
flights.groupby('airline')['origin'].size().nsmallest(3)
# Out:
# airline
# EV    171
# OH    257
# MQ    373
# Name: origin, dtype: int64

# %% [markdown]
# ### Exercise 2
#
# <span style="color:green; font-size:16px">For each airline, find the 75th percentile of flight distance. Use a custom aggregation function.</span>

# %%
def seventh_per(s):
    return s.quantile(.75)

# %%
flights.groupby('airline').agg(percentile_75 = ('distance', seventh_per))
# Out:
#          percentile_75
# airline
# 9E               852.0
# AA              1558.0
# AS              2402.0
# B6              2381.0
# DL              1587.0
# EV               514.5
# F9              1476.0
# MQ               612.0
# NK              1379.0
# OH               500.0
# OO               912.0
# UA              1635.0
# VX              2475.0
# WN              1024.0
# YV              1075.0
# YX               912.0

# %% [markdown]
# ### Exercise 3
#
# <span style="color:green; font-size:16px">For each airline, find out what percentage of its flights leave on a Tuesday. Use a custom aggregation function.</span>

# %%
def tuesday_flights(s):
    return (s.dt.day_name() == 'Tuesday').mean()

# %%
flights.groupby('airline').agg(pct_tuesday = ('date',tuesday_flights))
# Out:
#          pct_tuesday
# airline
# 9E          0.144648
# AA          0.146195
# AS          0.138101
# B6          0.134958
# DL          0.143544
# EV          0.157895
# F9          0.128834
# MQ          0.160858
# NK          0.128437
# OH          0.167315
# OO          0.143405
# UA          0.139875
# VX          0.132867
# WN          0.152687
# YV          0.138546
# YX          0.150000

# %% [markdown]
# ### Exercise 4
#
# <span style="color:green; font-size:16px">Optimize exercise 2 without using a custom aggregation. What is the performance difference?</span>

# %%
flights['is_tues'] = flights['date'].dt.day_name() == 'Tuesday'
flights.groupby('airline').agg(pct_tuesday = ('is_tues', 'mean'))
# Out:
#          pct_tuesday
# airline
# 9E          0.144648
# AA          0.146195
# AS          0.138101
# B6          0.134958
# DL          0.143544
# EV          0.157895
# F9          0.128834
# MQ          0.160858
# NK          0.128437
# OH          0.167315
# OO          0.143405
# UA          0.139875
# VX          0.132867
# WN          0.152687
# YV          0.138546
# YX          0.150000

# %% [markdown]
# ### Exercise 5
#
# <span style="color:green; font-size:16px">The range of salaries per department was calculated using the `min_max` custom function from the beginning of this chapter. Use this same function to calculate the range of distance for each airline. Then calculate this range again without a custom function.</span>

# %%
def min_max(s):
    return s.max() - s.min()

# %%
flights.groupby('airline').agg(in_ax = ('distance', min_max))
# Out:
#           in_ax
# airline
# 9E       1297.0
# AA       2515.0
# AS       2468.0
# B6       2520.0
# DL       2610.0
# EV        876.0
# F9       2042.0
# MQ        831.0
# NK       2166.0
# OH        835.0
# OO       1405.0
# UA       2505.0
# VX       2468.0
# WN       1940.0
# YV       1192.0
# YX       1320.0

# %% [markdown]
# ### Exercise 6
#
# <span style="color:green; font-size:16px">Which origin airport has the highest percentage of its flights cancelled?</span>

# %%
(flights.groupby('origin').agg(pct_cancelled = ('cancelled','mean'))
                          .nlargest(1, 'pct_cancelled')
                          .round(3) * 100)
# Out:
#         pct_cancelled
# origin
# BOS               3.4

# %% [markdown]
# # Transform and Filter with Groupby

# %% [markdown]
# ## Exercises
#
# Execute the cell below to reread the college dataset and use it for the exercises below.

# %%
cols = ['instnm', 'stabbr', 'relaffil', 'satvrmid', 'satmtmid', 'ugds']
college = pd.read_csv('../data/college.csv', usecols=cols, index_col='instnm')
college.head(3)
# Out:
#                                     stabbr  relaffil  satvrmid  satmtmid  \
# instnm
# Alabama A & M University                AL         0     424.0     420.0
# University of Alabama at Birmingham     AL         0     570.0     565.0
# Amridge University                      AL         1       NaN       NaN
#
#                                         ugds
# instnm
# Alabama A & M University              4206.0
# University of Alabama at Birmingham  11383.0
# Amridge University                     291.0

# %% [markdown]
# ### Exercise 1
#
# <span style="color:green; font-size:16px">Filter the college DataFrame for states that have more than 500,000 total undergraduate students. Can you verify your results?</span>

# %%
def more_500(s):
    return s['ugds'].sum() > 500000

# %%
col = college.groupby('stabbr').filter(more_500)
col.head()
# Out:
#                                      stabbr  relaffil  satvrmid  satmtmid  \
# instnm
# Prince Institute-Southeast               IL         0       NaN       NaN
# Everest College-Phoenix                  AZ         1       NaN       NaN
# Collins College                          AZ         0       NaN       NaN
# Empire Beauty School-Paradise Valley     AZ         1       NaN       NaN
# Empire Beauty School-Tucson              AZ         0       NaN       NaN
#
#                                         ugds
# instnm
# Prince Institute-Southeast              84.0
# Everest College-Phoenix               4102.0
# Collins College                         83.0
# Empire Beauty School-Paradise Valley    25.0
# Empire Beauty School-Tucson            126.0

# %%
col.groupby('stabbr')['ugds'].sum()
# Out:
# stabbr
# AZ     520439.0
# CA    2304492.0
# FL     959753.0
# IL     599816.0
# NY     993623.0
# OH     537638.0
# PA     604942.0
# TX    1277374.0
# Name: ugds, dtype: float64

# %% [markdown]
# ### Exercise 2
#
# <span style="color:green; font-size:16px">Filter the college DataFrame for states that have a an average undergraduate student population greater than 2,500 and have more than 30 religiously affiliated schools. Can you verify your results?</span>

# %%
def ugds_reg(s):
    return s['ugds'].mean() > 2500 and s['relaffil'].sum() > 30

# %%
college.groupby('stabbr').filter(ugds_reg)
# Out:
#                                                    stabbr  relaffil  satvrmid  \
# instnm
# Academy of Art University                              CA         0       NaN
# ITT Technical Institute-Rancho Cordova                 CA         0       NaN
# Academy of Chinese Culture and Health Sciences         CA         0       NaN
# The Academy of Radio and TV Broadcasting               CA         0       NaN
# Avalon School of Cosmetology-Alameda                   CA         0       NaN
# ...                                                   ...       ...       ...
# WestMed College - Merced                               CA         1       NaN
# Vantage College                                        TX         1       NaN
# SAE Institute of Technology  San Francisco             CA         1       NaN
# Bay Area Medical Academy - San Jose Satellite L...     CA         1       NaN
# Excel Learning Center-San Antonio South                TX         1       NaN
#
#                                                     satmtmid    ugds
# instnm
# Academy of Art University                                NaN  9885.0
# ITT Technical Institute-Rancho Cordova                   NaN   500.0
# Academy of Chinese Culture and Health Sciences           NaN     NaN
# The Academy of Radio and TV Broadcasting                 NaN    14.0
# Avalon School of Cosmetology-Alameda                     NaN   253.0
# ...                                                      ...     ...
# WestMed College - Merced                                 NaN     NaN
# Vantage College                                          NaN     NaN
# SAE Institute of Technology  San Francisco               NaN     NaN
# Bay Area Medical Academy - San Jose Satellite L...       NaN     NaN
# Excel Learning Center-San Antonio South                  NaN     NaN
#
# [1982 rows x 5 columns]

# %% [markdown]
# ### Exercise 3
#
# <span style="color:green; font-size:16px">The maximum SAT score for each test is 800. Create a new column in the college dataset that shows each school's percentage of maximum for each SAT score.</span>

# %%
def sat_800(s):
    return (s / 800).round(3) * 100

# %%
college[['satvrmid_pct', 'satmtmid_pct']] = (college[['satvrmid','satmtmid']] / 800).round(2) * 100
college
# Out:
#                                                    stabbr  relaffil  satvrmid  \
# instnm
# Alabama A & M University                               AL         0     424.0
# University of Alabama at Birmingham                    AL         0     570.0
# Amridge University                                     AL         1       NaN
# University of Alabama in Huntsville                    AL         0     595.0
# Alabama State University                               AL         0     425.0
# ...                                                   ...       ...       ...
# SAE Institute of Technology  San Francisco             CA         1       NaN
# Rasmussen College - Overland Park                      KS         1       NaN
# National Personal Training Institute of Cleveland      OH         1       NaN
# Bay Area Medical Academy - San Jose Satellite L...     CA         1       NaN
# Excel Learning Center-San Antonio South                TX         1       NaN
#
#                                                     satmtmid     ugds  \
# instnm
# Alabama A & M University                               420.0   4206.0
# University of Alabama at Birmingham                    565.0  11383.0
# Amridge University                                       NaN    291.0
# University of Alabama in Huntsville                    590.0   5451.0
# Alabama State University                               430.0   4811.0
# ...                                                      ...      ...
# SAE Institute of Technology  San Francisco               NaN      NaN
# Rasmussen College - Overland Park                        NaN      NaN
# National Personal Training Institute of Cleveland        NaN      NaN
# Bay Area Medical Academy - San Jose Satellite L...       NaN      NaN
# Excel Learning Center-San Antonio South                  NaN      NaN
#
#                                                     satvrmid_pct  satmtmid_pct
# instnm
# Alabama A & M University                                    53.0          52.0
# University of Alabama at Birmingham                         71.0          71.0
# Amridge University                                           NaN           NaN
# University of Alabama in Huntsville                         74.0          74.0
# Alabama State University                                    53.0          54.0
# ...                                                          ...           ...
# SAE Institute of Technology  San Francisco                   NaN           NaN
# Rasmussen College - Overland Park                            NaN           NaN
# National Personal Training Institute of Cleveland            NaN           NaN
# Bay Area Medical Academy - San Jose Satellite L...           NaN           NaN
# Excel Learning Center-San Antonio South                      NaN           NaN
#
# [7535 rows x 7 columns]

# %% [markdown]
# ### Use the City of Houston dataset
#
# Execute the following cell to read in the City of Houston employee dataset and then use it for the following exercises.

# %%
emp = pd.read_csv('../data/employee.csv')
emp.head(3)
# Out:
#                    dept                       title   hire_date    salary  \
# 0                Police             POLICE SERGEANT  2001-12-03  87545.38
# 1                 Other  ASSISTANT CITY ATTORNEY II  2010-11-15  82182.00
# 2  Houston Public Works     SENIOR SLUDGE PROCESSOR  2006-01-09  49275.00
#
#     sex      race
# 0  Male     White
# 1  Male  Hispanic
# 2  Male     Black

# %% [markdown]
# ### Exercise 4
#
# <span style="color:green; font-size:16px">Filter it so that only position titles with an average salary of 100,000 remain. Can you verify your results?</span>

# %%
def avg_100k(s):
    return s.mean() > 100000

# %%
emp.groupby('title')[['salary']].filter(avg_100k)
# Out:
#           salary
# 16     107744.00
# 17     115821.42
# 19      95783.00
# 39     112270.00
# 48     115835.98
# ...          ...
# 24159  342784.00
# 24219   92104.00
# 24238  162915.00
# 24267   98703.00
# 24270  140595.00
#
# [817 rows x 1 columns]

# %%
emp.groupby('title').filter(lambda df: df['salary'].mean() > 100000)
# Out:
#                          dept                                     title  \
# 16                      Other       ASSOCIATE JUDGE OF MUNICIPAL COURTS
# 17                     Police                          POLICE COMMANDER
# 19                      Other      ASSISTANT DIRECTOR (EXECUTIVE LEVEL)
# 39     Houston Airport System  DEPUTY ASSISTANT DIRECTOR (EXECUTIVE LEV
# 48                       Fire                      ASSISTANT FIRE CHIEF
# ...                       ...                                       ...
# 24159                    Fire                              PHYSICIAN,MD
# 24219                   Other           ERP BUSINESS SYSTEMS CONSULTANT
# 24238                   Other  DEPUTY CIO - IT INFRASTRUCTURE (EXE LVL)
# 24267    Houston Public Works                      SUPERVISING ENGINEER
# 24270                   Other      ASSISTANT DIRECTOR (EXECUTIVE LEVEL)
#
#         hire_date     salary     sex      race
# 16     2005-11-09  107744.00    Male  Hispanic
# 17     1983-02-07  115821.42    Male     White
# 19     2002-05-28   95783.00  Female  Hispanic
# 39     2017-08-15  112270.00    Male     Black
# 48     1994-11-07  115835.98    Male  Hispanic
# ...           ...        ...     ...       ...
# 24159  2017-01-09  342784.00    Male     Asian
# 24219  2001-07-09   92104.00  Female     White
# 24238  2006-12-04  162915.00    Male     White
# 24267  2011-03-21   98703.00  Female     Asian
# 24270  2012-07-14  140595.00    Male     White
#
# [817 rows x 6 columns]

# %% [markdown]
# ### Exercise 5
#
# <span style="color:green; font-size:16px">Filter the employee dataset so that only position titles with at least 5 employees and an average salary of 80,000 remain. Can you verify the results?</span>

# %%
def avg_80k(s):
    return s.mean() > 80000 and len(s) >= 5

# %%
emp.groupby('title')['salary'].filter(avg_80k)
# Out:
# 0         87545.38
# 1         82182.00
# 16       107744.00
# 17       115821.42
# 19        95783.00
#            ...
# 24271     85372.00
# 24276     89623.00
# 24288     89590.02
# 24292     95004.00
# 24307          NaN
# Name: salary, Length: 3172, dtype: float64

# %%
emp.groupby('title').filter(lambda df: len(df) >= 5 and df['salary'].mean() > 80000)
# Out:
#                          dept                                   title  \
# 0                      Police                         POLICE SERGEANT
# 1                       Other              ASSISTANT CITY ATTORNEY II
# 16                      Other     ASSOCIATE JUDGE OF MUNICIPAL COURTS
# 17                     Police                        POLICE COMMANDER
# 19                      Other    ASSISTANT DIRECTOR (EXECUTIVE LEVEL)
# ...                       ...                                     ...
# 24271                   Other                        DIVISION MANAGER
# 24276                   Other                        DIVISION MANAGER
# 24288                    Fire                          DISTRICT CHIEF
# 24292  Houston Airport System  SENIOR STAFF ANALYST (EXECUTIVE LEVEL)
# 24307                  Police                         POLICE SERGEANT
#
#         hire_date     salary     sex      race
# 0      2001-12-03   87545.38    Male     White
# 1      2010-11-15   82182.00    Male  Hispanic
# 16     2005-11-09  107744.00    Male  Hispanic
# 17     1983-02-07  115821.42    Male     White
# 19     2002-05-28   95783.00  Female  Hispanic
# ...           ...        ...     ...       ...
# 24271  1989-10-30   85372.00    Male     Black
# 24276  1993-09-21   89623.00    Male     Black
# 24288  1982-06-28   89590.02    Male     White
# 24292  2018-11-19   95004.00    Male     Black
# 24307  1984-05-29        NaN    Male     White
#
# [3172 rows x 6 columns]

# %% [markdown]
# ### Exercise 6
#
# <span style="color:green; font-size:16px">Add a column to the DataFrame that contains the median salary based on department, sex, and race.</span>

# %%
emp['med_sal_dept_sex_race'] = emp.groupby(['dept',  'sex', 'race'])['salary'].transform('median')
emp.head(10)
# Out:
#                    dept                       title   hire_date    salary  \
# 0                Police             POLICE SERGEANT  2001-12-03  87545.38
# 1                 Other  ASSISTANT CITY ATTORNEY II  2010-11-15  82182.00
# 2  Houston Public Works     SENIOR SLUDGE PROCESSOR  2006-01-09  49275.00
# 3                Police       SENIOR POLICE OFFICER  1997-05-27  75942.10
# 4                Police       SENIOR POLICE OFFICER  2006-01-23  69355.26
# 5                 Other        SENIOR ACCOUNT CLERK  2017-10-09  44616.00
# 6  Houston Public Works    ADMINISTRATIVE ASSISTANT  2005-08-29  39998.00
# 7                Police              POLICE OFFICER  2008-03-31  68116.62
# 8                  Fire                FIRE FIGHTER  2015-08-01  48189.70
# 9                Police       SENIOR POLICE OFFICER  1993-08-30  75942.10
#
#       sex      race  med_sal_dept_sex_race
# 0    Male     White               73479.00
# 1    Male  Hispanic               47445.00
# 2    Male     Black               38813.00
# 3    Male  Hispanic               68116.62
# 4    Male     White               73479.00
# 5  Female     Black               52915.00
# 6  Female     Black               39707.00
# 7    Male     Asian               65755.00
# 8    Male     White               62540.14
# 9    Male     Black               68116.62

# %% [markdown]
# ### Exercise 7
#
# <span  style="color:green; font-size:16px">Add a new column, `pct_max_dept_sex`, to the employee DataFrame that holds the employees percentage of the maximum salary for each department and sex. For instance, if a male HPD employee makes 80,000 and the maximum male HPD salary is 120,000 then the value for this employee would be 80,000/120,000 or .666. Verify this value for the first employee.</span>

# %%
def max_percent(s):
    return s / s.max()

# %%
emp['pct_max_dept_sex']  = emp.groupby(['dept', 'sex'])['salary'].transform(max_percent)
emp['pct_max_dept_sex']
# Out:
# 0        0.312662
# 1        0.298844
# 2        0.227809
# 3        0.271222
# 4        0.247697
#            ...
# 24303    0.271222
# 24304    0.371585
# 24305    0.162612
# 24306    0.359954
# 24307         NaN
# Name: pct_max_dept_sex, Length: 24308, dtype: float64
